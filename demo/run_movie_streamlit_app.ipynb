# %% [markdown]
# **Dependecies:**
# - Download updated versions of `movie_rag_app.py` and `movie_rag_pipeline.py`.
# - Make sure `movie_titles` and `movie_titles` collections are set up for chroma db.
# - If not see `build_movie_names_vectordb.py` on how to build the collection.
#   - **Note:** You'll most likely need to run the script in colab in order to update the google drive with your chroma DB.
# - Either:
#   - Contact for one of the contributors for the `ngrok authtoken`
#   - Or create your own `authtoken` at: https://ngrok.com/docs/start

# %%
# Mount Google Drive to access and save files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Change to a folder you have both the `movie_rag_app.py` and the `movie_rag_pipeline.py`.

# %%
# Sanity check: make sure app and pipeline are in the folder
# %cd /content/drive/MyDrive/movie_rag_app
# !ls
# Out:
# /content/drive/MyDrive/movie_rag_app
# movie_rag_app.py  movie_rag_pipeline.py  __pycache__

# %% [markdown]
# Change to the folder you have the `chroma_db` file in.

# %%
# Sanity check: make sure chromadb is in folder
# !ls /content/drive/MyDrive/chroma_db
# Out:
# 45bb7f0a-f0d0-4e8f-a6fc-aeb05d7d4dd1  chroma.sqlite3
# 4f3236c5-07fb-48f8-a926-1e045561c48e

# %%
# install dependecies
# !pip install -q streamlit chromadb sentence-transformers transformers accelerate bitsandbytes
# !pip install -q pyngrok

# %%
# Set up ngrok authtoken
from pyngrok import ngrok
ngrok.set_auth_token("3CbEldwfcWeNCn0KM7QyAZahOag_rRtTQXxZ3rkX3H8rosqJ")

# %%
# Start streamlit
# !streamlit run movie_rag_app.py \
  --server.port 8501 \
  --server.address 0.0.0.0 \
  --server.headless true \
  >/content/streamlit.log 2>&1 &

# %%
# Give streamlit time to start
import time
import requests

for _ in range(30):
    try:
        r = requests.get("http://127.0.0.1:8501")
        if r.status_code == 200:
            print("Streamlit is up")
            break
    except:
        pass
    time.sleep(2)
else:
    print("Streamlit did not start in time")
# Out:
# Streamlit is up

# %%
# Print url and run app
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://styling-coasting-flashy.ngrok-free.dev" -> "http://localhost:8501"
